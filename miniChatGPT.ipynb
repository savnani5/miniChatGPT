# %%
# GPT implementation inspired from Andrej Karpathy

import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 3000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(2023)

# %%
# Load Arthur Conan Doyle's Sherlock Holmes
with open('sherlock-holmes_stories.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %% [markdown]
# Rather than use character level tokenizer lets use tiktoken; Openai's implementation of a Byte Pair Encoding (BPE) tokenizer

# %%
# !pip install tiktoken
import tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2023.7.22)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.5.1

# %%
enc = tiktoken.get_encoding("gpt2")
vocab_size = 50257

# %%
# Train and test splits
data = torch.tensor(enc.encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GPT(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = GPT()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# 6.684497 M parameters
# step 0: train loss 10.9617, val loss 10.9613
# step 100: train loss 5.3294, val loss 5.3900
# step 200: train loss 5.0935, val loss 5.1017
# step 300: train loss 4.8549, val loss 4.8343
# step 400: train loss 4.6772, val loss 4.7018
# step 500: train loss 4.5675, val loss 4.6165
# step 600: train loss 4.4586, val loss 4.5138
# step 700: train loss 4.3849, val loss 4.4488
# step 800: train loss 4.3528, val loss 4.4014
# step 900: train loss 4.2550, val loss 4.3694
# step 1000: train loss 4.2396, val loss 4.3271
# step 1100: train loss 4.1914, val loss 4.2759
# step 1200: train loss 4.1487, val loss 4.2755
# step 1300: train loss 4.1323, val loss 4.2555
# step 1400: train loss 4.1091, val loss 4.2058
# step 1500: train loss 4.0792, val loss 4.2038
# step 1600: train loss 4.0327, val loss 4.1894
# step 1700: train loss 4.0127, val loss 4.1553
# step 1800: train loss 3.9738, val loss 4.1376
# step 1900: train loss 3.9679, val loss 4.1296
# step 2000: train loss 3.9643, val loss 4.0930
# step 2100: train loss 3.9010, val loss 4.1027
# step 2200: train loss 3.9140, val loss 4.0810
# step 2300: train loss 3.8984, val loss 4.0973
# step 2400: train loss 3.8558, val loss 4.0671
# step 2500: train loss 3.8301, val loss 4.0341
# step 2600: train loss 3.8309, val loss 4.0476
# step 2700: train loss 3.8065, val loss 4.0206
# step 2800: train loss 3.8011, val loss 4.0224
# step 2900: train loss 3.7799, val loss 4.0086
# step 2999: train loss 3.7586, val loss 3.9951

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(enc.decode(m.generate(context, max_new_tokens=1000)[0].tolist()))
# Out:
# ! It is nothing for much far. But you can't know you to give
#      my new telegraph. None. I have wanted a swift-ion with an embarrassed
#      on the railwayidity, followed all, and never sitting at a long as he had left
#      from the details, deadall swiftly Pool's, had not into my arms of such a
#      o'clock during a state. They had escaped outside the window, but one of
#      others. No spot in business off, a consultingivingutableger swinging by
#      one.
#
#      "'There are fifteen this detective,' I could be at that Sherlock Holmes. "Do,
#      we should be nohire on this faith, I their horses at once twice
#      he, and began which he had. Good for her my goose had been happy Scripture.
#      Knowledge, and the permission no doubt was compare of that detailist is one
#      sp slightly about something arranged which whom he
#      gave his move there was three shown at once note in.
#
#      "Then my mind, you is well the town and, Mr. His line,
#      slowly Sholtoly fingers. I cannot be
#      invaluable in any blank upon the weapon at considerable the mental'or
#      night ch than fish. There you know that marked it," said he went upon home. "I
#      said doubt, Sir Charles, I had suggested as I do. 'How not one of
#      though you know that we should strike it more you faintly certain home, of
#      this led 10, caught the room was at leaving her the rigWeps beforehand and
#     board. I knewite, that you will walk that times was about
#      this morning. How like her face moreids. It was which more modern, and
#      as if the plainly thatler as once died traces. I could never know you
#      made that it, became since could night not marry her. Hudson was very
#      insol, but no only go round my tid Sholtoman died to I
#      should swear this good."
#
#      "The reserve any interesting sign sheisly. It was a photograph before her,
#      whether ever Ryder he was full of the trembling, and nevered
#      that a noble of this matter, so far, with a glass angry. Surely
#      it may follow the details that. And he were up and open at the
#      satisfying crime was moving by the room on Co during the kind, for one upon
#      afterwards, and jew the devil that he is a Bound eaten off to send,
#      Mrs. Itese, the conspir with the fog borrow taking that Greeky,
#      and nothing after good rather landsly of an arm which. I was Hind
#      "I fancy Gley to have done whether I propose. We good I's impossible
#     ." He is really in put the cushion, and I tossed served to see so that
#      Through as steady would place the truth, and we are one
#      Half least you."
#
#      "Rem has the other, sir, and after far as you know to be
#      very attention some heart and the hotel the dark vowed. No doubt there my
#      these possible as Godfrey may call that count out. The
#      man could not vex the wind of opinion castart.'
#
#      "'ice a expose evidence Wednesday young public might was a retain, we
#      struck another 195 Inspector a nutshell enemies, and the ceiling took here, with the
#      very white mission-handitched.
#
#      "That is any fault."
#
#      "So Scotland Yard contribution yourself," she, "It's mine will the lin him
#      nearly have blazing. Dr. locked had caught, but its stategetthat
#      before, with such an old old person. Either,th of suppression, nose, and
#      drove in those little mouth?"
#
#      "The wargrave, that he can like a days time."
#
#      "You cannot have in this quarrel?"
#
#      "You must be twenty days that I'm attained found

# %%
# !pip install transformers
from transformers import pipeline
sentiment_pipeline = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.2 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2
# Downloading (…)lve/main/config.json:   0%|          | 0.00/949 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/338 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# Downloading (…)solve/main/bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %%
inps = ["I'm the king of the world!",
        "I'll be back.",
        "The cake is a lie",
        "To be forgotten is worse than death",
        "All happy families are alike; each unhappy family is unhappy in its own way.",
        "You don't need a reason to help people",
        ]
res = sentiment_pipeline(inps)

for i in range(len(inps)):
  res[i]['text'] = inps[i]
  print(res[i])
# Out:
# {'label': 'POS', 'score': 0.9771729707717896, 'text': "I'm the king of the world!"}
# {'label': 'POS', 'score': 0.5481613278388977, 'text': "I'll be back."}
# {'label': 'NEG', 'score': 0.758118748664856, 'text': 'The cake is a lie'}
# {'label': 'NEG', 'score': 0.8209368586540222, 'text': 'To be forgotten is worse than death'}
# {'label': 'NEU', 'score': 0.787423849105835, 'text': 'All happy families are alike; each unhappy family is unhappy in its own way.'}
# {'label': 'NEU', 'score': 0.8731083273887634, 'text': "You don't need a reason to help people"}

# %%
def get_reward(text, mode):
  sent = sentiment_pipeline(text)
  if mode == '+ve':
    labels = torch.tensor([a['label']=='POS' for a in sent],dtype=torch.float16).unsqueeze(-1).to(device)
  elif mode == '-ve':
    labels = torch.tensor([a['label']=='NEG' for a in sent],dtype=torch.float16).unsqueeze(-1).to(device)
  else:
    raise ValueError('Unknown Mode')

  weights = torch.tensor([a['score'] for a in sent],dtype=torch.float32).unsqueeze(-1).to(device)

  rewards = labels * weights # (B, 1)

  return rewards

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]
print('Rewards in +ve mode')
list(zip(inps, flatten(get_reward(inps, '+ve').tolist())))
# Out:
# Rewards in +ve mode
# [("I'm the king of the world!", 0.9771729707717896),
#  ("I'll be back.", 0.5481613278388977),
#  ('The cake is a lie', 0.0),
#  ('To be forgotten is worse than death', 0.0),
#  ('All happy families are alike; each unhappy family is unhappy in its own way.',
#   0.0),
#  ("You don't need a reason to help people", 0.0)]

# %%
print('Rewards in -ve mode')
list(zip(inps, flatten(get_reward(inps, '-ve').tolist())))
# Out:
# Rewards in -ve mode
# [("I'm the king of the world!", 0.0),
#  ("I'll be back.", 0.0),
#  ('The cake is a lie', 0.758118748664856),
#  ('To be forgotten is worse than death', 0.8209368586540222),
#  ('All happy families are alike; each unhappy family is unhappy in its own way.',
#   0.0),
#  ("You don't need a reason to help people", 0.0)]

# %%
eval_interval_rlhf = 20
max_iters_rlhf = 1000

# %%
from torch.distributions import Categorical
class RLHF(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, idx, targets=None):
        return self.model(idx, targets)

    def generate(self, idx, max_new_tokens, block_size, ref_model=None):
        # idx is (B, T) array of indices in the current context
        log_probs = torch.tensor([]).to(device)
        log_probs_ref = torch.tensor([]).to(device)

        for i in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]

            # get the predictions
            logits, loss = self(idx_cond)

            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)

            # logits define instance of Iategorical class
            m = Categorical(logits=logits)

            # sample from the distribution
            idx_next = m.sample()

            # get the log probability and append to running sequence
            log_probs_idx_next = m.log_prob(idx_next)
            log_probs = torch.cat((log_probs, log_probs_idx_next.view(-1,1)), dim=1)

            if ref_model is not None:
              # get log probability of sample idx_next under the reference model
              logits_ref, _ = ref_model(idx_cond)
              logits_ref = logits_ref[:, -1, :] # becomes (B, C)

              m_ref = Categorical(logits=logits_ref)
              log_probs_ref_idx_next = m_ref.log_prob(idx_next)
              log_probs_ref = torch.cat((log_probs_ref, log_probs_ref_idx_next.view(-1,1)), dim=1)

            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next.view(-1,1)), dim=1) # (B, T+1)

        return idx, log_probs, log_probs_ref

# %%
import copy
ref_model = copy.deepcopy(model)

# %%
import time
import numpy as np

RLHFmodel = RLHF(model)
RLHFmodel.to(device)

ref_model.to(device)

actor_optimizer = torch.optim.AdamW(RLHFmodel.parameters(), lr=1e-3)
X, Y = get_batch('train') # fetch the very first batch
X = torch.ones((X.shape[0], 1), dtype=torch.long).to(device) # for now there is no prompt
X = X*enc.encode('The')[0] # start with ''The'
t0  = time.time()
max_new_tokens = block_size
rews_all = []
actor_loss_all = []
mode = '+ve'
ref_coef = 0.2
e_coef = 0.1
for iter in range(max_iters_rlhf):

  states, log_probs, log_probs_ref = RLHFmodel.generate(
      X, max_new_tokens, block_size, ref_model=ref_model)

  states = states[:,-max_new_tokens:]
  log_probs = log_probs[:,-max_new_tokens:] # (B, max_new_tokens)
  if ref_model is not None:
    log_probs_ref = log_probs_ref[:,-max_new_tokens:] # (B, max_new_tokens)

  rewards = get_reward([enc.decode(s.tolist()) for s in states], mode)

  pg = (rewards+ref_coef*log_probs_ref-e_coef*log_probs)* log_probs.squeeze()

  # log(1) = 0
  # -log(1/N) = log(N)

  # when ref_coef=e_coef this is equivalent to penalising for KL divergence
  # pg = (rewards-ref_coef*(log_probs-log_probs_ref)* log_probs.squeeze()

  actor_loss = -pg.sum()

  actor_optimizer.zero_grad(set_to_none=True)
  actor_loss.backward()
  actor_optimizer.step()

  rews_all.append(rewards.mean().detach().cpu().numpy())
  actor_loss_all.append(actor_loss.detach().cpu().numpy())

  if iter % eval_interval_rlhf == 0:
      t1 = time.time()
      print('\n')
      print(f'iter: {iter}, time: {t1-t0}')
      print(f'Actor loss: {np.mean(actor_loss_all[-eval_interval_rlhf:])}')
      print(f'rets: {np.mean(rews_all[-eval_interval_rlhf:])}')

      textRLHF = RLHFmodel.generate(X, 2*max_new_tokens, block_size, ref_model=None)[0]
      for i in range(1):
          text_i = textRLHF[i,:]
          print(enc.decode(text_i.tolist()))
# Out:
# iter: 0, time: 3.634800910949707
# Actor loss: -1474.7510986328125
# rets: 0.0
# The dangerous Deep stood Castging back to ascertain of yours of
#      closed. There was never looked intelligent, though, and a large hill, 'I have
#      a be provided for by such trouble? You will be residence Lal very slight there
#      my bedroom. They
#
#
# iter: 20, time: 79.31979060173035
# Actor loss: -1491.014892578125
# rets: 0.026934346184134483
# The checkpoint
#
#      "No?"
#
#      "My sir all there was a strange motives
#      blue; so it has always a death, the face portion of modern
#      Holmes, and I asked, not by my family to hear to go which the
#
#
#
# iter: 40, time: 150.0303521156311
# Actor loss: -1437.0550537109375
# rets: 0.020550068467855453
# The utter fellow are caused-lady?"
#
#      "Oh," remarked Holmes, "I commend to say three. Inspector operations, seemed to do man,
#      whether you know how have gone under see they are sure before.'
#
#
#
#
# iter: 60, time: 220.75266480445862
# Actor loss: -1507.364990234375
# rets: 0.01972144842147827
# The north is some half as I am
#      that I began to his back to go out such a rapidly
#      day that pour
#      said. "We are that you have will me a shortly." It was
#      rather certain to an empty34
#
#
# iter: 80, time: 293.13792276382446
# Actor loss: -1467.6021728515625
# rets: 0.02809544838964939
# The bark was
#      vengeance of terr until So me, the instant later burned which
#      have now you this end before her helpless close with that I saw that a sorcerer Hotel
#      my room as
#      hurled this man as though showed on a half feet
#
#
# iter: 100, time: 364.50256991386414
# Actor loss: -1452.7342529296875
# rets: 0.030344391241669655
# The position was I can, with you the woman he was confined, me that
#      I had in his good halting as possible it."
#
#      Sherlock Holmes had looked round and sorry, in the key obviouslyass, and as
#      Holmes threw the m and regretted of his
#
#
# iter: 120, time: 436.77292227745056
# Actor loss: -1417.325927734375
# rets: 0.043972600251436234
# The servants of my sight in an Colonel and the thirty
#      and passed had nothing on in the vicub, a house on
#      where it is very not quite it's train of the next
#      loft. He was a very deep glaring, standing, and could not
#
#
# iter: 140, time: 508.17246437072754
# Actor loss: -1378.1846923828125
# rets: 0.05243610218167305
# The holy of town. "Wibank you would start of my
#      secrecy to him--"hire:
#
#      "come Such more was the hill of unsolved it."
#
#      "Oh, that I have just told me to not frightly. Whatkerchief from
#
#
# iter: 160, time: 581.9782404899597
# Actor loss: -1368.585205078125
# rets: 0.05509640648961067
# The tu garments-room for some bullet cou surveillance.
#      From anyone when herself as in the matter to-room. Myuppen with a seventeen.
#      that a verdict was the front to tea intimate. It was convinced, no privateies made
#      for any
#
#
# iter: 180, time: 653.6229796409607
# Actor loss: -1401.712890625
# rets: 0.04741392284631729
# The punishment article, exactly it off our books."
#
#      "I should do not such a low affairs; Watson, and I don't
#      not wear opening such particular pretty some otherwise. I stop down as came down and
#      would see that right contents in begin complexion
#
#
# iter: 200, time: 725.6138472557068
# Actor loss: -1444.139404296875
# rets: 0.024550175294280052
# The eye is capable friendship with a lady, with locked
#      when the darkness came hard aurnal. Ofience hadement tob every story
#      full at shattered, either. What is not shoe, if man was of fright, to v
#      was my steady clues I
#
#
# iter: 220, time: 797.0134906768799
# Actor loss: -1476.7313232421875
# rets: 0.015954824164509773
# The mask of my
#      utmost position.
#      "This watch; Mr. Baskerville outer details by something by cass which
#      the secretary by the door.
#
#      "Are, how, I'llWhat ever lie, but I could suppose
#
#
# iter: 240, time: 868.4870600700378
# Actor loss: -1401.777587890625
# rets: 0.05306506156921387
# The hair, that he handed. The order with his
#      free- already15 off.
#
#      "Good one at Green and if it start. You could
#      ask those usual if that fair telegram to find you sprang up,
#      and I
#
#
# iter: 260, time: 942.8680326938629
# Actor loss: -1367.635986328125
# rets: 0.04553326591849327
# The son when I find it. Yet, grasped a bare story became for
#      known you doing this morning to be a very remarkable woman to escape to certain,
#     ged her that hands that is a Wire, but that if at least upon
#      this Op suarted
#
#
# iter: 280, time: 1013.7616081237793
# Actor loss: -1377.7474365234375
# rets: 0.05819501355290413
# The and pal with a High lion of coarse and his
#     ab same- nerves here led together.
#
#      "I am going to point!' anything else, this! It is no it very well
#      will be this fourous. I'll find that not to see
#
#
# iter: 300, time: 1086.8762092590332
# Actor loss: -1399.5875244140625
# rets: 0.05448787286877632
# The boat keep
#      Lestrade withrap.
#
#      "Yes, it is as I escaped."
#
#      "But eleven now?" 'Yes, man uttered, insteadly.'
#
#
#
#
#
#
# iter: 320, time: 1158.1822600364685
# Actor loss: -1302.267822265625
# rets: 0.06467451900243759
# The flowers Sir A door- Indeed, Doctor, which when I had been
#      may stand not quite brilliantly so always initial on the scene, and come to B
#      haveday to the reach. When we were a mile of
#      London. She was a sc jargon
#
#
# iter: 340, time: 1229.4070806503296
# Actor loss: -1361.6331787109375
# rets: 0.07256614416837692
# The kitchen. If you can have--to you
#      cameacre and swton to me, too trap, it can have been gone. That
#      in order; but now anything and I'll use not come to see how it end which
#      remember mention to Through
#
#
# iter: 360, time: 1300.7052748203278
# Actor loss: -1393.48095703125
# rets: 0.04375794902443886
# The wheels is more you. The g!"
#
#      "All as in an injured precise box into it. You can have sealed,
#      every easy pounds for the future?"
#
#      "In so it will not be a threatening known summon that little cro spite."
#
#
#
#
# iter: 380, time: 1371.864290714264
# Actor loss: -1325.753173828125
# rets: 0.0703488290309906
# The gard at which he is a very soon hunting
#      over. I knew that which I cluc here, by the whole other science
#      of my hair-ilant, and the secretary her that nothing in the glent
#      of the end into the ring, to
#
#
# iter: 400, time: 1443.075157880783
# Actor loss: -1375.784423828125
# rets: 0.06655170023441315
# The conspir, and figure fierce but well among the date with way for be,
#      with presented in his voices.  The same flight Hotel- record his hand in the but
#      stood and delic novelened out, in the
#      threatened. I have had told him
#
#
# iter: 420, time: 1514.8754920959473
# Actor loss: -1336.32080078125
# rets: 0.06695137917995453
# The narrowly stepping by employment, which is
#      of single Ach nice a small lover, and of advertisement in my thinlic.'"    which is
#      such good pocket in my compliments prer. It was the body attacks to it
#      with him. Mr.
#
#
# iter: 440, time: 1588.7662522792816
# Actor loss: -1346.6402587890625
# rets: 0.05985739082098007
# The elderlyisse tricks. thrill."
#
#      "I saw you for cases. Someone it's grasp. Every country I
#      notably irritony. certainly, however he's nothing.
#      my However by a man's own wife and closeman cameban. I had a
#
#
# iter: 460, time: 1660.1003234386444
# Actor loss: -1346.1431884765625
# rets: 0.05984053760766983
# The old Saturday, with out from the door
#      himself Experience and one the notes for her in the long blow and
#      achievements, which they took a apt had could take like a lantern in
#      publishers job. I found that I should not, trail, and came
#
#
# iter: 480, time: 1731.5540626049042
# Actor loss: -1397.1494140625
# rets: 0.06949643045663834
# The desk of that 'I quite
#      Tr glad yet close home that you are yourHeadine."
#
#      "combatelled, this?"
#
#      "You very bad going on soul of.
#
#      "And that you may, rushing to be the cr
#
#
# iter: 500, time: 1802.5215110778809
# Actor loss: -1274.266845703125
# rets: 0.0847160816192627
# The prophetic in such become gone which
#      came our way in years in such a tall those months. That ch
#      medicine in the stable, however, the head of our door was only any great
#      inland s houses affected again you. The envelope again gave its detectives
#
#
# iter: 520, time: 1873.910091638565
# Actor loss: -1371.552490234375
# rets: 0.04696983844041824
# Theep and ch
#      the case and with his
#      thoughts. He has the cross strained without metal."
#
#      "Pier!"
#
#      "What during Be largestly."
#
#      "He's gone by that night."
#
#
#
#
# iter: 540, time: 1945.9746942520142
# Actor loss: -1337.7032470703125
# rets: 0.06855374574661255
# The letter found entirely a left-ouseded in the t.
#      inside Mous, and the advantage of it?"
#
#      "He is a hugeagged in the attention you?"
#
#      "You are then heard looking facts upon the door, or about eleven noble.
#
#
# iter: 560, time: 2019.405731678009
# Actor loss: -1359.2115478515625
# rets: 0.05762665718793869
# The stable face upon his own newcomer. "I have been aware by surprised."
#
#      "There is was the paragraph stimul upon this questions at deny an hour man's
#      purpose in it. Well, and so day abstract showedmatic to the sun it and first up to some
#
#
#
# iter: 580, time: 2094.537982940674
# Actor loss: -1362.204345703125
# rets: 0.06056720018386841
# The tempting. With and sound us
#      stretched his emer staring.
#
#      "And the pedal, I know that he would notrav to hear.
#      Henry Cunningham, but I had stood that he was thrust with mine, finally
#      of the garden
#
#
# iter: 600, time: 2167.7424006462097
# Actor loss: -1379.055908203125
# rets: 0.055487506091594696
# The man was four lantern."
#
#      "No, we are very good."
#
#      "I Hope it. It was my sister's this oak and arist getting
#      of it once, with one side which would
#      be except to be so in a
#
#
# iter: 620, time: 2240.5785748958588
# Actor loss: -1325.506103515625
# rets: 0.048109348863363266
# The June have Card."
#
#      "ap ring's well onwards point into the tossed indeed. Now,
#      instead for a rooms," he over eyes exploriteout. now "Yes, leaving
#      there could have passedanut upstairs as you promise that the stairs was good
#
#
# iter: 640, time: 2313.9404401779175
# Actor loss: -1372.173583984375
# rets: 0.038062967360019684
# The door. "Well, sir. On the bureau, interesting last, sir!" said Holmes of his room,
#      while; living it as I was a stop in the necksician,
#      I am breaking that this that you must upon the thing must be starting if
#
#
#
# iter: 660, time: 2388.2956840991974
# Actor loss: -1284.4820556640625
# rets: 0.07146107405424118
# The only that there was direct by whom Why,
#      my brother hurled that same broke Scotlandened of the police. It is glad of the command
#      air of that when he and had given a white bandain off of month who
#      cameily. It is a
#
#
# iter: 680, time: 2463.1103291511536
# Actor loss: -1276.60302734375
# rets: 0.06771237403154373
# The cultivate at my son, of yourseven.
#
#      "Very good twenty surprised I got forward at, no problem's true. I'm
#      at us, Watson God you know that I knew that we may see that you
#      can get it about, and the
#
#
# iter: 700, time: 2536.6341891288757
# Actor loss: -1294.35400390625
# rets: 0.06785465776920319
# The head voice. In a blackmailargie or him for
#      least upon a great pleasure, for news are early, and last their common end of
#     ,crop to find the massiveilles-- never meet its intended together; there is without trap,
#      Reg badly
#
#
# iter: 720, time: 2612.0435621738434
# Actor loss: -1276.009521484375
# rets: 0.08967225253582001
# The same pointsitious. "I should go all
#      to until muching my own spirits. But if I must report "' develop have so
#      louding, and insol andoeeddagger forever. This is its bestropolis
#      lives expression. It was a quarrel
#
#
# iter: 740, time: 2684.8914489746094
# Actor loss: -1362.4669189453125
# rets: 0.0677478164434433
# The gnire, mate and it before the old
#      cannot stand had become but a large in muff to see, that? There is
#      gain upward of her seat, but I'll undoubtedly nothing, from them at
#     ? St. This marriage except the reference of
#
#
# iter: 760, time: 2757.5137112140656
# Actor loss: -1324.3162841796875
# rets: 0.07533635944128036
# The loft,I should you take you now you. At some
#      toilet send asked!"
#
#      "That,'
#
#      "I.'
#
#      " put at a talk."
#
#      "No he wished to see may know God you,
#
#
# iter: 780, time: 2834.263259410858
# Actor loss: -1353.9422607421875
# rets: 0.055238425731658936
# The gas perila floor indoors, a goose in front wellascar, and full
#      in the details, short attitude and d! command he is a visit
#     ipping."
#
#             "When my opinion if we were a take my hand
#
#
# iter: 800, time: 2906.989006757736
# Actor loss: -1312.596923828125
# rets: 0.08456749469041824
# The wonderful confirmed Sh Ecc.' It
#      had knownly, but in light to correspond off him as he visited
#      glove. Ah the night, I have brought bear and wrong,
#      and I came into the Grimes."
#
#      "On me again
#
#
# iter: 820, time: 2979.3538887500763
# Actor loss: -1265.796142578125
# rets: 0.09792916476726532
# The Ha, and the moment if the
#      day of the own devoted. It was the centre of several
#      endless waiting. Thatlessly for you. There is the sofa as if I have thrown
#      it at some of excellentrugged words. He was able.
#
#
#
#
# iter: 840, time: 3052.051203250885
# Actor loss: -1219.1907958984375
# rets: 0.07938489317893982
# The photograph would be served in
#      between the interview."
#
#      "The east was driven of it enough to track, don't get her, where
#      might touch my barrels, and ten as evening by in the stone.dden
#      clear-table
#
#
# iter: 860, time: 3124.464566230774
# Actor loss: -1295.3203125
# rets: 0.07602798938751221
# The grand Office round which would
#      marry that you do have seen her with the matter upon the st OF OFine. He calls
#      and murderer, turning to his terms through the sendering me soaringhed husband now
#      to you, and there before we began
#
#
# iter: 880, time: 3201.5519535541534
# Actor loss: -1214.842041015625
# rets: 0.09297479689121246
# The stick of the door. I thought him."
#
#      "And by among San?"
#
#      "I will be to examine."
#
#      "If you knows that on either fantastic little time!" He could not wish, however,
#      exine a man
#
#
# iter: 900, time: 3273.756813287735
# Actor loss: -1229.126708984375
# rets: 0.08980468660593033
# The intellectual
#      from this letter."
#
#      "Exactly," said he-- remembers concealed a change off
#      to keep me, and he was up with great Professor into his power of a smash listening
#      Imperial.
#
#      "'I He
#
#
# iter: 920, time: 3346.7026193141937
# Actor loss: -1255.145751953125
# rets: 0.10504484176635742
# The strongest into the information of his moment. I have not ever your heart
#      well. I cannot have always understand that the other points are glad to
#     treatment that when to expose but she
#      for every small light upon a thing.
#
#      Hopkins
#
#
# iter: 940, time: 3419.144994020462
# Actor loss: -1129.2432861328125
# rets: 0.17375482618808746
# The road?"
#
#      "He are one of pocket to stay, longs as he swept over
#      biting. I have fast, so more than she sinister for someington recommended,
#      weminded horribly," said Holmes.
#
#      "I don't
#
#
# iter: 960, time: 3492.4219999313354
# Actor loss: -1181.21875
# rets: 0.13880760967731476
# The Grimpenia.! It had hope him behind a
#      doors of nervous as an wine of your surgery. sister of inferences up,
#     urg Square,be?"
#
#      "But of the thought, Jack Grork deals."
#
#      "
#
#
# iter: 980, time: 3564.743410587311
# Actor loss: -1269.469482421875
# rets: 0.10487484931945801
# The land swiftly
#      and came into a dense fashionise. But it was settled?"
#
#      "You did not hold so on the mine to have been
#      to escape."
#
#      "When do, moment if it is so condition in the cat."

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(enc.decode(m.generate(context, max_new_tokens=1000)[0].tolist()))
# Out:
# ! What has a yes as I confess. It may
#      are told the truth, Watson. What goes there was power in us butt
#      rapidly more serious and forgotten romance. almost worn up to played his collar upon our
#      heart.
#
#      "He could was sure a pleasure anything since I am contrary to all that your
#      running, and you will night such a cab ones andored whoseither
#      considering in an old plot's plastererences until its cutting we were done; there finished keep
#      by the wood, and before it was no conversation close the writing. adjoiningas-house
#      had comic up her incess at significance, so. We was always loved up, that
#      time this, extra would reconstruct such absurd such no detail serves and
#      of within his excellent. Hugo the joy to meet hand, observ
#      against portion, and threw up a short above his throat from thinking from this
#      work had entirelyings of someone, here by your room, and his may hear
#      before hoass, matter and I had not carry."
#
#      "That will be on firm to lose to Saltred in that he knew haunted her
#      and a shadow that importance of C
#
#      "Come- strang any deeply, and it could have brought up it as there." 'ask
#      travelled, well, the whole hours to me, therefore to do him.historic not know it told
#      them to naturally up and a case ready if I asked; motionic career in his head
#      it over any detectives expression. But you've moved on the affair sat out out, but
#      the betterable and next will in a two days before me rest on which she was happyxt
#      into his life, and that end of this debt for we stood down
#      fellow, as rich in an old table,
#      after to do so that it was of an murdered little place of the one. Private
#      put Colonel'scoat a two very cynical dinner to understand a thickcoat down with
#      in the postical. But the cab, that I drew that very brother with him, what
#      will cause backwards had a amazing a man, should not what would he may not been pond,
#      well such a great two dark safe and watches in and earnest.
#
#      "Ah there stood beat four lookary--place canwood me, it!"
#
#      "B convenience in the your back, with a Greek case, who rode laughing down struck as a
#      objection before we have relieved to some day inWhen gro you like him upon so
#      with they were great eagerem and I followed, and wondered to then,
#      that at veryAPTER become over the garden in thety, as I would called
#      one of you do, and that it is you to be satisfaction,
#      and made retiring I
#      had no opinion well revenax. And this pride, the first chanceedire, in
#      Mrs. Holmes and dest my opinion into the door and a great way with it. I'll be
#      you, then?" I became sworn with anything with him with reading dressed, leaving how may
#      night that it can tell me to find in the
#      fashion shifted and stories the peculiarled peepm Secretary. As we saw me to keep it,
#      Brixtoniveker."
#
#      "I came in thedrawn eye. It is no grave Mortimer. A cat-to member finding
#      himself, whom I stood as it and not one, throwing Godic and very kind under the
#      very neighbourhood itselfig agent.
#
#      "If a vague pockets, sir, I am. Even with a surprised, conversation, God brother was on
#      this very quarrel and turning over the hill, and I gave me was really a end,
#      man, croach, in the dear green more sealed, and the apple could still have
#      upon him to give other, and I am keep Mr as he may go in
#      preserved. Scott some poisonousuddled happened spinning, and she were acted to. It's a tiger,
#      place at the station
